# %%
# if you do not have 'nltk', the following command should work "python -m pip install nltk"
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#pip install gensim --user

# %%
# Run the following code if the package is not installed: "pip install num2words"
#!pip install num2words

# %%
#pip install emoji

# %%
from collections import defaultdict
from array import array
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import math
import numpy as np
import collections
from numpy import linalg as la
import time
import string
import re
import emoji
import pandas as pd
from gensim.models.word2vec import Word2Vec
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

import json

# %%
docs_path = 'dataset_tweets_WHO.txt'
with open(docs_path) as fp:
    tweets = json.loads(fp.read())

print("Number of tweets:", len(tweets))
# Out:
# Number of tweets: 2399

# %%
lang = {} 
for tweet in tweets:
    if tweets[tweet]['lang'] in lang:
        lang[tweets[tweet]['lang']] += 1
    else:
        lang[tweets[tweet]['lang']] = 1
        
print("Languages:", lang)
print(sum(lang.values()) == len(tweets)) # Check is the number of extracted languages is the same as the number of tweets
# Out:
# Languages: {'en': 2353, 'es': 19, 'in': 2, 'fr': 7, 'und': 1, 'tl': 1, 'de': 6, 'ar': 2, 'ru': 2, 'uk': 1, 'ps': 1, 'ja': 4}
# True

# %%
def process_word(word, stop_words):
    """
    Preprocess each word of the tweet getting rid of URLs, punctuation sings and stop words
    
    Argument:
    word -- string (text) to be preprocessed
    stop_words -- list of stop words to get rid of
    
    Returns:
    word - the resulting processed word. False in case we don't want that word
    """
    
# Eliminate URLs
    word = re.sub(r'http\S+', '', word) 

# Eliminate ampersands
    word = re.sub(r'&\S+', '', word) 

    if not word:
        return False

# Get rid of punctuation marks except "#" and "@"
    if word[0] == '#':
        word = '#' + word.translate(str.maketrans('', '', string.punctuation)) 
        return word

    elif word[0] == '@':
        word = '@' + word.translate(str.maketrans('', '', string.punctuation)) 
        return word
    
    elif '¿' in word:
        word = word.replace('¿', '')
    
    else:
        word = word.translate(str.maketrans('', '', string.punctuation))

# Get rid of strings like '-'
    if len(word) <= 1 and not word.isdigit(): 
        return False
    
# Eliminate the stopwords 
    elif word not in stop_words: 
        return word

# %%
def build_terms(line):
    """
    Preprocess the tweet text calling the process_word function, stemming,
    transforming in lowercase and return the tokens of the text.
    
    Argument:
    line -- string (text) to be preprocessed
    
    Returns:
    line - a list of tokens corresponding to the input text after the preprocessing
    """

    stemmer = PorterStemmer()
    
    stop_words = set()
    for lang in stopwords.fileids():
         stop_words |= set(stopwords.words(lang))
            
    line = emoji.get_emoji_regexp().sub("", line)
    
    line= line.lower()## Transform in lowercase
    line= line.split() ## Tokenize the text to get a list of terms
    templine=[]
    for word in line:      
        word = process_word(word, stop_words)
        if word:
            templine.append(word)
            
    line= templine
    line= [stemmer.stem(word) for word in line] ## perform stemming
    return line

# %%
def create_index_tfidf(tweets, X):
    """
    Implement the inverted index
    
    Argument:
    lines -- collection of tweets
    
    Returns:
    index - the inverted index (implemented through a Python dictionary) containing terms as keys and the corresponding
    list of tweets where these keys appears in (and the positions) as values.
    """
    index = defaultdict(list)
    tf = defaultdict(list)
    df = defaultdict(int)
    idf = defaultdict(float)
    num_tweets = len(tweets)
    
    likes_tw = defaultdict(list)
    followers_user = defaultdict(list)
    tweet2vec = defaultdict(list)
    rt_tw = defaultdict(list)
    
    for tweet in tweets:
        line = tweets[tweet]['full_text']
        line_arr = line.replace("\n", ' ')
        tweet_id = tweet
        terms = build_terms(''.join(line_arr))
        
        if len(terms) == 0:
            continue
        
        tweet2vec[tweet] = np.array([0.0]*len(X[terms[0]]))
        
        for term in terms:
            tweet2vec[tweet] += np.array(X[term])
        
        tweet2vec[tweet] = tweet2vec[tweet] / len(terms)
        
        ## ===============================================================        
        ## create the index for the current page and store it in current_page_index (current_page_index)
        ## current_tweet_index ==> { ‘term1’: [current_tweet, [list of positions]], ...,‘term_n’: [current_tweet, [list of positions]]}

        ## Example: if the curr_tweet has id 1 and his text is 
        ##"web retrieval information retrieval":

        ## current_tweet_index ==> { ‘web’: [1, [0]], ‘retrieval’: [1, [1,4]], ‘information’: [1, [2]]}

        ## the term ‘web’ appears in tweet 1 in positions 0, 
        ## the term ‘retrieval’ appears in tweet 1 in positions 1 and 4
        ## ===============================================================

        current_tweet_index = {}

        for position, term in enumerate(terms):  ## terms contains the text of the tweet
            try:
                # if the term is already in the index for the current tweet (current_tweet_index)
                # append the position to the corresponding list
                current_tweet_index[term][1].append(position)
            except:
                # Add the new term as dict key and initialize the array of positions and add the position
                current_tweet_index[term]=[tweet_id, array('I',[position])] #'I' indicates unsigned int (int in Python)

        #normalize term frequencies
        # Compute the denominator to normalize term frequencies (formula 2 above)
        # norm is the same for all terms of a tweet.
        norm = 0
        for term, posting in current_tweet_index.items():
            # posting will contain the list of positions for current term in current tweet. 
            # posting ==> [current_tweet, [list of positions]] 
            # you can use it to infer the frequency of current term.
            norm += len(posting[1]) ** 2
        norm = math.sqrt(norm)

        #calculate the tf(dividing the term frequency by the above computed norm) and df weights
        for term, posting in current_tweet_index.items():
            # append the tf for current term (tf = term frequency in current tweet/norm)
            tf[term].append(np.round(len(posting[1])/norm,4)) ## SEE formula (1) above
            #increment the tweet frequency of current term (number of tweets containing the current term)
            df[term] += 1# increment DF for current term
            
            likes_tw[term].append(tweets[posting[0]]['favorite_count']) # Compute the amount of likes of the tweet
            followers_user[term].append(tweets[posting[0]]['user']['followers_count']) # Compute the amount of followers of the user who tweeted
            rt_tw[term].append(tweets[posting[0]]['retweet_count'])

        #merge the current tweet index with the main index
        for term_page, posting_page in current_tweet_index.items():
            index[term_page].append(posting_page)

        # Compute IDF following the formula (3) above. HINT: use np.log
        for term in df:
            idf[term] = np.round(np.log(float(num_tweets/df[term])), 4)

    return index, tf, df, idf, likes_tw, followers_user, rt_tw, tweet2vec

# %%
def check_index(word, index): # Function that checks and returns if a given word is in the created index
    if word in index:
        return index[word]
    else:
        return []

# %%
def rank_tweets(terms, tweets, index, idf, tf):
    """
    Perform the ranking of the results of a search based on the tf-idf weights
    
    Argument:
    terms -- list of query terms
    tweets -- list of tweets, to rank, matching the query
    index -- inverted index data structure
    idf -- inverted document frequencies
    tf -- term frequencies
    title_index -- mapping between page id and page title
    
    Returns:
    Print the list of ranked tweets
    """
    # I'm interested only on the element of the tweetVector corresponding to the query terms 
    # The remaining elements would became 0 when multiplied to the query_vector
    tweet_vectors = defaultdict(lambda: [0] * len(terms)) # I call tweet_vectors[k] for a nonexistent key k, the key-value pair (k,[0]*len(terms)) will be automatically added to the dictionary
    query_vector = [0] * len(terms)

    # compute the norm for the query tf
    query_terms_count = collections.Counter(terms)  # get the frequency of each term in the query. 
    # Example: collections.Counter(["hello","hello","world"]) --> Counter({'hello': 2, 'world': 1})
    #HINT: use when computing tf for query_vector

    query_norm = la.norm(list(query_terms_count.values()))

    for termIndex, term in enumerate(terms):  #termIndex is the index of the term in the query
        if term not in index:
            continue
            
        ## Compute tf*idf(normalize TF as done with tweets)
        query_vector[termIndex]=query_terms_count[term]/query_norm * idf[term]

        # Generate tweet_vectors for matching tweets
        for tweet_index, (tweet, postings) in enumerate(index[term]):
            # Example of [tweet_index, (tweet, postings)]
            # 0 (26, array('I', [1, 4, 12, 15, 22, 28, 32, 43, 51, 68, 333, 337]))
            # 1 (33, array('I', [26, 33, 57, 71, 87, 104, 109]))
            # term is in tweet 26 in positions 1,4, .....
            # term is in tweet 33 in positions 26,33, .....

            #tf[term][0] will contain the tf of the term "term" in the tweet 26            
            if tweet in tweets:
                tweet_vectors[tweet][termIndex] = tf[term][tweet_index] * idf[term]  # check if multiply for idf

    # Calculate the score of each tweet 
    # compute the cosine similarity between queyVector and each tweetVector:
    # We use the dot product because in case of normalized vectors it corresponds to the cosine similarity
    
    tweet_scores=[[np.dot(curtweetVec, query_vector), tweet] for tweet, curtweetVec in tweet_vectors.items() ]
    tweet_scores.sort(reverse=True)

    result_tweets = [x[1] for x in tweet_scores]

    if len(result_tweets) == 0:
        print("No results found, try again")
        return False

    return result_tweets, tweet_scores

# %%
def rank_tweets_ours(terms, tweets, index, idf, tf, likes, followers, retweets, all_tweets):
    """
    Perform the ranking of the results of a search based on the tf-idf weights
    
    Argument:
    terms -- list of query terms
    tweets -- list of tweets, to rank, matching the query
    index -- inverted index data structure
    idf -- inverted document frequencies
    tf -- term frequencies
    title_index -- mapping between page id and page title
    
    Returns:
    Print the list of ranked tweets
    """
    # I'm interested only on the element of the tweetVector corresponding to the query terms 
    # The remaining elements would become 0 when multiplied to the query_vector
    tweet_vectors = defaultdict(lambda: [0] * len(terms)) # I call tweet_vectors[k] for a nonexistent key k, the key-value pair (k,[0]*len(terms)) will be automatically added to the dictionary
    query_vector = [0] * len(terms)

    # compute the norm for the query tf
    query_terms_count = collections.Counter(terms)  # get the frequency of each term in the query. 
    # Example: collections.Counter(["hello","hello","world"]) --> Counter({'hello': 2, 'world': 1})
    #HINT: use when computing tf for query_vector
    query_norm = la.norm(list(query_terms_count.values()))
    
##############

    for termIndex, term in enumerate(terms):  #termIndex is the index of the term in the query
        #if term not in index:
        #    continue
        like_avg = sum(likes[term]) / len(likes[term])
        rt_avg = sum(retweets[term]) / len(retweets[term])
        followers_avg = sum(followers[term]) / len(followers[term])
        ## Compute tf*idf(normalize TF as done with tweets)

        query_vector[termIndex]=query_terms_count[term]/query_norm * idf[term] + (like_avg + rt_avg/followers_avg)*100

        # Generate tweet_vectors for matching tweets
        for tweet_index, (tweet, postings) in enumerate(index[term]):
            # Example of [tweet_index, (tweet, postings)]
            # 0 (26, array('I', [1, 4, 12, 15, 22, 28, 32, 43, 51, 68, 333, 337]))
            # 1 (33, array('I', [26, 33, 57, 71, 87, 104, 109]))
            # term is in tweet 26 in positions 1,4, .....
            # term is in tweet 33 in positions 26,33, .....

            #tf[term][0] will contain the tf of the term "term" in the tweet 26            
            if tweet in tweets:
                tweet_vectors[tweet][termIndex] = tf[term][tweet_index] * idf[term] + (like_avg + rt_avg/followers_avg)*100 #all_tweets[tweet]['favorite_count']  # TODO: check if multiply for idf
    
    # Calculate the score of each tweet 
    # compute the cosine similarity between queyVector and each tweetVector:
    # HINT: you can use the dot product because in case of normalized vectors it corresponds to the cosine similarity
    # see np.dot
    
    tweet_scores=[[np.dot(curtweetVec, query_vector), tweet] for tweet, curtweetVec in tweet_vectors.items() ]
    tweet_scores.sort(reverse=True)

    result_tweets = [x[1] for x in tweet_scores]

    if len(result_tweets) == 0:
        print("No results found, try again")
        return False

    return result_tweets, tweet_scores

# %%
def rank_tweets_word2vec(terms, tweets, index, idf, tf, model, tweet2vec):
    """
    Perform the ranking of the results of a search based on the tf-idf weights
    
    Argument:
    terms -- list of query terms
    tweets -- list of tweets, to rank, matching the query
    index -- inverted index data structure
    idf -- inverted document frequencies
    tf -- term frequencies
    title_index -- mapping between page id and page title
    
    Returns:
    Print the list of ranked tweets
    """
    
    # We will first have to compute each query as a normalized vector of words
    X = model.wv
    query_vector = np.array([0.0]*len(X[terms[0]])) # Create the query vector
    
    for word in terms:
        query_vector += np.array(X[word]) # Add the words
    
    query_vector = query_vector/len(terms) # Normalize
    
    tweet_vectors = {}
    
    for tweet in tweets:
        tweet_vectors[tweet] = tweet2vec[tweet]

#############
    # Calculate the score of each tweet 
    # compute the cosine similarity between queyVector and each tweetVector:
    # HINT: you can use the dot product because in case of normalized vectors it corresponds to the cosine similarity
    # see np.dot
    
    tweet_scores=[[np.dot(curtweetVec, query_vector), tweet] for tweet, curtweetVec in tweet_vectors.items() ]
    tweet_scores.sort(reverse=True) # Compute and sort by scores

    result_tweets = [x[1] for x in tweet_scores] # Return the top ranked tweets of the query

    if len(result_tweets) == 0:
        print("No results found, try again")
        return False

    return result_tweets, tweet_scores

# %%
def query_output(query, index, idf, tf, likes, followers, retweets,  tweets, mode, model = None):
    
    query_words = build_terms(query) # Separate query by preprocessed terms
    
    docs = {}
    for word in query_words: # Save the documents in which query terms appear
        docs[word] = [val[0] for val in check_index(word, index)]
        if len(docs[word]) == 0:
            return ['No tweets found'], None # Reference for when the query terms are not found in any tweet
    
    doc_list = list(docs.values())
    final_doc_list = doc_list[0]
    for list_ in doc_list:
        final_doc_list = list(set(final_doc_list) & set(list_))
        
    # Depending on the selected mode, the computed score and output ranking will be one or another
    # - Mode 1: Our score and ranking, taking into account the number of likes and followers
    # - Mode 2: Word2Vec score
    # - Otherwise: Use the initial tf-idf score
    if mode == 1:
        ranked_tweets, tweet_scores = rank_tweets_ours(query_words, final_doc_list, index, idf, tf, likes, followers, retweets, tweets)
    elif mode == 2:
        ranked_tweets, tweet_scores = rank_tweets_word2vec(query_words, final_doc_list, index, idf, tf, model, tweet2vec)
    else:
        ranked_tweets, tweet_scores = rank_tweets(query_words, final_doc_list, index, idf, tf)
    
    return ranked_tweets, tweet_scores
        
def display_tweets(list_): # Function that will be used to display the resulting list of ranked tweets
    if 'No tweets found' in list_:
        print('No tweets found matching this query')
        return 
    
    if len(list_) == 0:
        return 'No tweets'
    
    for tw in list_:
        print('\033[1m'+'Tweet index:'+'\033[0m', tw) # Tweet
        print('\033[1m'+'Tweet:'+'\033[0m', tweets[tw]['full_text']) # Text
        print('\033[1m'+'Username:'+'\033[0m', tweets[tw]['user']['name']) # Username
        print('\033[1m'+'Date:'+'\033[0m', tweets[tw]['created_at']) # Date of creation
        print('\033[1m'+'Hashtags:'+'\033[0m', [d['text'] for d in tweets[tw]['entities']['hashtags']]) # Hashtags
        print('\033[1m'+'Favourites:'+'\033[0m', tweets[tw]['favorite_count']) # Likes
        print('\033[1m'+'Retweets:'+'\033[0m', tweets[tw]['retweet_count']) # Retweets
        print('\033[1m'+'URL:'+'\033[0m', 'https://twitter.com/'+tweets[tw]['user']['screen_name']+'/status/'+str(tweets[tw]['id']), '\n') # URL
        print('\n')
    return

# %%
clean_tweets = {}
for tweet in tweets:
    line = tweets[tweet]['full_text']
    line_arr = line.replace("\n", ' ')
    terms = build_terms(''.join(line_arr))
    clean_tweets[tweet] = terms
    
sentences = clean_tweets.values()

model = Word2Vec(sentences, workers=4, min_count=1, window=10, sample=1e-5)

# %%
start_time = time.time() # Mark the time it takes for the code to create the index
index, tf, df, idf, likes, followers, retweets, tweet2vec = create_index_tfidf(tweets, model.wv)
print("Total time to create the index: {} seconds".format(np.round(time.time() - start_time, 2)))
# Out:
# Total time to create the index: 320.19 seconds

# %%
queries = ['covid19 vaccine', 'death risk', 'world pandemic', 'health service', 'developing countries', 'molta caca']

mode_ = 1

for query_text in queries:
    out, scores = query_output(query_text, index , idf, tf, likes, followers, retweets, tweets, mode_, model)
    if out == ['No tweets found']: # In case no tweets are found
        print('No tweets found matching query:', query_text)
    else:
        print(out[:20])
        print('\033[1m'+'Top 20 tweets from query "{}":'.format(query_text)+'\033[0m')
        display_tweets(out[:20])
        print("###############################################################\n\n")
# Out:
# ['2257', '1959', '904', '2190', '2186', '1045', '2188', '2193', '935', '2195', '1772', '2187', '1565', '1310', '266', '2191', '1849', '310', '2202', '2192']
# Top 20 tweets from query "covid19 vaccine":
# Tweet index: 2257
# Tweet: Q&amp;A #AskWHO on COVID-19 vaccines effectiveness https://t.co/FEdfOREhjn
# Username: World Health Organization (WHO)
# Date: Wed Jun 30 16:12:43 +0000 2021
# Hashtags: ['AskWHO']
# Favourites: 219
# Retweets: 85
# URL: https://twitter.com/WHO/status/1410270080873598979
#
#
#
# Tweet index: 1959
# Tweet: 💉💉💉💉
# 💉💉💉💉
# 💉💉💉💉
# 💉💉💉💉
# 💉💉💉💉                 💉💉💉💉
# 💉💉💉💉                 💉💉💉💉
#
# COVID-19 vaccines     COVID-19 vaccines
# in 10 countries             in the rest of the 🌍
#
# #VaccinEquity is 🗝️ to ending the pandemic, together!
#
# #WorldEmojiDay
# Username: World Health Organization (WHO)
# Date: Sat Jul 17 16:24:23 +0000 2021
# Hashtags: ['VaccinEquity', 'WorldEmojiDay']
# Favourites: 3486
# Retweets: 1517
# URL: https://twitter.com/WHO/status/1416433609091653633
#
#
#
# Tweet index: 904
# Tweet: #COVID19 variants &amp; vaccines:
#
# ✅ COVID-19 vaccines provide strong protection against serious illness &amp; death
# ✅ Get all necessary doses to develop maximum protection
# ✅ Continue practicing all the protective behaviours even after vaccination to stop COVID-19 variants
# Username: World Health Organization (WHO)
# Date: Mon Sep 06 08:09:59 +0000 2021
# Hashtags: ['COVID19']
# Favourites: 352
# Retweets: 169
# URL: https://twitter.com/WHO/status/1434790971632336906
#
#
#
# Tweet index: 2190
# Tweet: "The sooner we start building more [#COVID19] vaccine hubs and upping global vaccine capacity, the sooner we can diminish deadly surges."-@DrTedros
# Username: World Health Organization (WHO)
# Date: Fri Jul 02 13:05:55 +0000 2021
# Hashtags: ['COVID19']
# Favourites: 591
# Retweets: 177
# URL: https://twitter.com/WHO/status/1410947847705530368
#
#
#
# Tweet index: 2186
# Tweet: "WHO issues Emergency Use Listings for [#COVID19] vaccines based on a stringent assessment of safety and efficacy and we expect all countries to recognise and accept those vaccines WHO has approved."-@DrTedros
# https://t.co/RPzpW7DApT
# Username: World Health Organization (WHO)
# Date: Fri Jul 02 13:10:20 +0000 2021
# Hashtags: ['COVID19']
# Favourites: 90
# Retweets: 36
# URL: https://twitter.com/WHO/status/1410948960429223940
#
#
#
# Tweet index: 1045
# Tweet: ▶️ If you have #COVID19, is it safe to breastfeed your baby❓
#
# ▶️ Is it safe to get vaccinated against COVID-19 if you are breastfeeding❓
#
# ▶️ How can you keep your baby safe while breastfeeding 🤱 if you have COVID-19❓
#
# Dr Laurence Grummer-Strawn explains in #ScienceIn5. https://t.co/QMAq9TMY7A
# Username: World Health Organization (WHO)
# Date: Mon Aug 30 10:43:22 +0000 2021
# Hashtags: ['COVID19', 'ScienceIn5']
# Favourites: 219
# Retweets: 105
# URL: https://twitter.com/WHO/status/1432292855037394953
#
#
#
# Tweet index: 2188
# Tweet: "Collectively we also made several asks to the G20 to accelerate global efforts to reach our [#COVID19] vaccine targets."-@DrTedros
# https://t.co/TOVXHPFt06
# Username: World Health Organization (WHO)
# Date: Fri Jul 02 13:07:43 +0000 2021
# Hashtags: ['COVID19']
# Favourites: 49
# Retweets: 26
# URL: https://twitter.com/WHO/status/1410948297808875521
#
#
#
# Tweet index: 2193
# Tweet: "There’s now some sharing of [#COVID19] vaccines happening but it’s still only a trickle, which is being outpaced by variants.
# In those countries whose hospitals are filling up, they need vaccines and other health tools right now."-@DrTedros
# Username: World Health Organization (WHO)
# Date: Fri Jul 02 13:03:33 +0000 2021
# Hashtags: ['COVID19']
# Favourites: 192
# Retweets: 92
# URL: https://twitter.com/WHO/status/1410947250595975171
#
#
#
# Tweet index: 935
# Tweet: RT @WHONepal: Nepal has administered more than 🔟million doses of COVID-19 💉💉💉, fully vaccinating 15% of its population. This feat wouldn't…
# Username: World Health Organization (WHO)
# Date: Thu Sep 02 16:38:12 +0000 2021
# Hashtags: []
# Favourites: 0
# Retweets: 101
# URL: https://twitter.com/WHO/status/1433469315710341130
#
#
#
# Tweet index: 2195
# Tweet: "It’s a challenge but we know it’s possible because already three billion [#COVID19] vaccines have been distributed."-@DrTedros
# Username: World Health Organization (WHO)
# Date: Fri Jul 02 13:02:05 +0000 2021
# Hashtags: ['COVID19']
# Favourites: 34
# Retweets: 11
# URL: https://twitter.com/WHO/status/1410946880121442305
#
#
#
# Tweet index: 1772
# Tweet: "The [#COVID19] pandemic has also demonstrated the urgent need to invest in scaling up local [vaccines] production capacity, especially in Africa."-@DrTedros
# Username: World Health Organization (WHO)
# Date: Mon Jul 26 14:56:32 +0000 2021
# Hashtags: ['COVID19']
# Favourites: 36
# Retweets: 12
# URL: https://twitter.com/WHO/status/1419672991848402946
#
#
#
# Tweet index: 2187
# Tweet: "Some countries, regions, have launched so called [#COVID19] vaccine certificates &amp; I want to make it very clear that it's important that these do not lead to discrimination against those people &amp; countries that have either a lack of vaccines or certain type of vaccine"-@DrTedros
# Username: World Health Organization (WHO)
# Date: Fri Jul 02 13:09:29 +0000 2021
# Hashtags: ['COVID19']
# Favourites: 246
# Retweets: 93
# URL: https://twitter.com/WHO/status/1410948745324281861
#
#
#
# Tweet index: 1565
# Tweet: Are you involved in the costing, budgeting or financing processes of #COVID19 vaccine delivery in your country?
#
# Join our 🆕 #OpenWHO course to learn how to use the COVID-19 Vaccine Introduction and deployment Costing Tool.
#
# 👉 https://t.co/vyXfuxXSDB https://t.co/XPr1caIFg6
# Username: World Health Organization (WHO)
# Date: Mon Aug 02 10:46:05 +0000 2021
# Hashtags: ['COVID19', 'OpenWHO']
# Favourites: 146
# Retweets: 31
# URL: https://twitter.com/WHO/status/1422146679051067400
#
#
#
# Tweet index: 1310
# Tweet: Getting vaccinated against #COVID19 helps protect you from getting sick. As soon as it's your turn, take your vaccine!
#
# All approved COVID-19 vaccines have been thoroughly tested, and all provide a high degree of protection against getting seriously ill &amp; dying from the disease. https://t.co/bYpU3WvpuM
# Username: World Health Organization (WHO)
# Date: Sun Aug 15 06:01:21 +0000 2021
# Hashtags: ['COVID19']
# Favourites: 299
# Retweets: 120
# URL: https://twitter.com/WHO/status/1426786068192366592
#
#
#
# Tweet index: 266
# Tweet: "Self-interest is natural, but there is enlightened self-interest. Vaccines can be produced and the world can be opened up. It's in our hands. We can end it [#COVID19] soon"-@DrTedros #VaccinEquity https://t.co/Ylz5mOkt1W
# Username: World Health Organization (WHO)
# Date: Fri Oct 01 22:03:02 +0000 2021
# Hashtags: ['COVID19', 'VaccinEquity']
# Favourites: 419
# Retweets: 152
# URL: https://twitter.com/WHO/status/1444060312534241286
#
#
#
# Tweet index: 2191
# Tweet: "In particularly, I urge those companies – BioNTech, Pfizer and Moderna – to share their know how so that we can speed up the development of new [#COVID19 vaccine] production."-@DrTedros
# Username: World Health Organization (WHO)
# Date: Fri Jul 02 13:05:19 +0000 2021
# Hashtags: ['COVID19']
# Favourites: 119
# Retweets: 59
# URL: https://twitter.com/WHO/status/1410947695276142598
#
#
#
# Tweet index: 1849
# Tweet: COVID-19 vaccine inequity is undermining 🌍 economic recovery. 🆕WHO, @UNDP and @BlavatnikSchool Dashboard on #VaccinEquity finds that low-income countries would add $38B to their GDP forecast if they had the same vaccination rate as high-income countries
# https://t.co/BsYF2eYL1G
# Username: World Health Organization (WHO)
# Date: Thu Jul 22 13:43:53 +0000 2021
# Hashtags: ['VaccinEquity']
# Favourites: 383
# Retweets: 168
# URL: https://twitter.com/WHO/status/1418205159188955137
#
#
#
# Tweet index: 310
# Tweet: RT @WHOAFRO: Join tomorrow's media briefing on the #COVID19 pandemic &amp; the global 10% COVID-19 vaccination milestones reached by countries…
# Username: World Health Organization (WHO)
# Date: Wed Sep 29 19:01:27 +0000 2021
# Hashtags: ['COVID19']
# Favourites: 0
# Retweets: 21
# URL: https://twitter.com/WHO/status/1443289841698025473
#
#
#
# Tweet index: 2202
# Tweet: "[COVID19] Delta has been detected in at least 98 countries and is spreading quickly in countries with low and high vaccination coverage."-@DrTedros
# Username: World Health Organization (WHO)
# Date: Fri Jul 02 12:54:35 +0000 2021
# Hashtags: []
# Favourites: 77
# Retweets: 55
# URL: https://twitter.com/WHO/status/1410944996241465345
#
#
#
# Tweet index: 2192
# Tweet: "New manufacturing hubs – including for mRNA [#COVID19] vaccines – are being developed but this could be accelerated by companies openly sharing technology and know-how."-@DrTedros
# Username: World Health Organization (WHO)
# Date: Fri Jul 02 13:04:18 +0000 2021
# Hashtags: ['COVID19']
# Favourites: 45
# Retweets: 22
# URL: https://twitter.com/WHO/status/1410947441692659717
#
#
#
# ###############################################################
#
#
# ['541', '1386', '1074', '1100', '323', '1875', '696', '793', '97', '1523', '508', '753', '2108', '1718', '969', '2289']
# Top 20 tweets from query "death risk":
# Tweet index: 541
# Tweet: #Breastfeeding 🤱 is a critical first #FoodSystem that ensures nutrition, health &amp; development of 👶.
#
# It's sustainable, not for profit &amp; it helps reduce:
# 📉preventable deaths
# 📉the risk of noncommunicable diseases
# 📉the risk of overweight/obesity
#
# 👉https://t.co/0MM8lIxZAx https://t.co/lphfIbfaYt
# Username: World Health Organization (WHO)
# Date: Thu Sep 23 15:52:59 +0000 2021
# Hashtags: ['Breastfeeding', 'FoodSystem']
# Favourites: 139
# Retweets: 52
# URL: https://twitter.com/WHO/status/1441068084022894592
#
#
#
# Tweet index: 1386
# Tweet: These therapies - artesunate, imatinib and infliximab – were selected by an independent expert panel for their potential in reducing the risk of death in hospitalized #COVID19 patients. https://t.co/K6tk22NnFf
# Username: World Health Organization (WHO)
# Date: Wed Aug 11 20:31:17 +0000 2021
# Hashtags: ['COVID19']
# Favourites: 57
# Retweets: 21
# URL: https://twitter.com/WHO/status/1425555442705575937
#
#
#
# Tweet index: 1074
# Tweet: "Cardiovascular diseases are the leading cause of death globally, and #hypertension is one of its main risk factors.
# More than 1.2 billion people live with hypertension."-@DrTedros
# https://t.co/zHeYfeQEFv
# Username: World Health Organization (WHO)
# Date: Wed Aug 25 15:49:12 +0000 2021
# Hashtags: ['hypertension']
# Favourites: 43
# Retweets: 21
# URL: https://twitter.com/WHO/status/1430557881372393486
#
#
#
# Tweet index: 1100
# Tweet: #Hypertension - or elevated blood pressure - is a serious medical condition that significantly increases the risks of ❤, 🧠, kidney &amp; other diseases.
#
# It is a major cause of premature death worldwide.
#
# 👉 https://t.co/PEXOASL1Tg https://t.co/QIAIsudIxE
# Username: World Health Organization (WHO)
# Date: Wed Aug 25 12:38:53 +0000 2021
# Hashtags: ['Hypertension']
# Favourites: 145
# Retweets: 70
# URL: https://twitter.com/WHO/status/1430509989249134596
#
#
#
# Tweet index: 323
# Tweet: Today is #WorldHeartDay 💗
#
# #Hypertension - or elevated blood pressure - is a serious medical condition that significantly increases the risks of ❤, 🧠, kidney &amp; other diseases. It is a major cause of premature death worldwide.
#
# 👉 https://t.co/PEXOASL1Tg https://t.co/L6vriEK1yc
# Username: World Health Organization (WHO)
# Date: Wed Sep 29 08:25:28 +0000 2021
# Hashtags: ['WorldHeartDay', 'Hypertension']
# Favourites: 229
# Retweets: 107
# URL: https://twitter.com/WHO/status/1443129790979051522
#
#
#
# Tweet index: 1875
# Tweet: The death of a parent or caregiver can have immediate &amp; lifelong harmful consequences for children incl. increased risks of:
# 🔸physical, emotional &amp; sexual violence
# 🔸#MentalHealth problems
# 🔸family poverty
#
# 👉https://t.co/2Gbl49N7pH https://t.co/R7t5f1Bp2C
# Username: World Health Organization (WHO)
# Date: Wed Jul 21 08:10:31 +0000 2021
# Hashtags: ['MentalHealth']
# Favourites: 189
# Retweets: 63
# URL: https://twitter.com/WHO/status/1417758877563736066
#
#
#
# Tweet index: 696
# Tweet: According to the WHO/@ILO Joint Estimates, the risk factors at work which cause the most deaths annually are
#
# 🕥 long working hours
# 🏭 air pollution, gases &amp; fumes
# 🤕 injuries.
#
# More in detail 👉https://t.co/mEXoBqYt5g #WorkersHealth https://t.co/WFXTglLppp
# Username: World Health Organization (WHO)
# Date: Fri Sep 17 14:29:01 +0000 2021
# Hashtags: ['WorkersHealth']
# Favourites: 132
# Retweets: 57
# URL: https://twitter.com/WHO/status/1438872624646529027
#
#
#
# Tweet index: 793
# Tweet: Patients who are critically ill with severe #COVID19 are at higher risk of developing and dying from #sepsis
#
# If #sepsis is not recognized early and managed promptly, it can lead to septic shock, multiple organ failure &amp; death
#
# https://t.co/sSLSPAQFv8 https://t.co/PI0zUFL7um
# Username: World Health Organization (WHO)
# Date: Mon Sep 13 09:48:20 +0000 2021
# Hashtags: ['COVID19', 'sepsis', 'sepsis']
# Favourites: 264
# Retweets: 120
# URL: https://twitter.com/WHO/status/1437352438906900486
#
#
#
# Tweet index: 97
# Tweet: It's #WorldMentalHealthDay.
#
# DYK: 1️⃣ in 1️⃣0️⃣0️⃣ deaths is by #suicide. For every suicide there are many more people who attempt suicide. A prior suicide attempt is an important risk factor.
# #LetsTalk https://t.co/cugMvd8oHu
# Username: World Health Organization (WHO)
# Date: Sun Oct 10 08:21:24 +0000 2021
# Hashtags: ['WorldMentalHealthDay', 'suicide', 'LetsTalk']
# Favourites: 298
# Retweets: 142
# URL: https://twitter.com/WHO/status/1447115031813017604
#
#
#
# Tweet index: 1523
# Tweet: Here is what we know about heart inflammation (myocarditis or pericarditis) and mRNA vaccines 👇
#
# The benefits of these vaccines 💉 greatly outweigh the risk of myocarditis &amp; pericarditis by preventing deaths &amp; hospitalisations due to #COVID19.
# Username: World Health Organization (WHO)
# Date: Wed Aug 04 10:49:48 +0000 2021
# Hashtags: ['COVID19']
# Favourites: 233
# Retweets: 101
# URL: https://twitter.com/WHO/status/1422872392418791439
#
#
#
# Tweet index: 508
# Tweet: New data from over 90 countries highlights that the progress made in the fight against #tuberculosis is at risk with #COVID19 disruptions leading to 1.4 million additional people missing out on access to TB care in 2020 alone &amp; over half a million deaths. https://t.co/2CFqV8NQek
# Username: World Health Organization (WHO)
# Date: Fri Sep 24 17:40:38 +0000 2021
# Hashtags: ['tuberculosis', 'COVID19']
# Favourites: 48
# Retweets: 17
# URL: https://twitter.com/WHO/status/1441457563665526788
#
#
#
# Tweet index: 753
# Tweet: @DrTedros "More than 5.7B [#COVID19 vaccine] doses have been administered globally, but only 2% of those have been administered in Africa. This leaves people at high risk of disease &amp; death exposed to a deadly virus against which many other people around the 🌍 enjoy protection"-@DrTedros
# Username: World Health Organization (WHO)
# Date: Tue Sep 14 14:12:04 +0000 2021
# Hashtags: ['COVID19']
# Favourites: 92
# Retweets: 45
# URL: https://twitter.com/WHO/status/1437781194498875401
#
#
#
# Tweet index: 2108
# Tweet: @DrTedros @G20 "This followed a comprehensive new analysis of 27 randomised trials involving nearly 11,000 patients, which found that treating hospitalised #COVID19 patients with IL-6 receptor blockers reduces the risk of death and the need for mechanical ventilation"-@DrTedros
# Username: World Health Organization (WHO)
# Date: Wed Jul 07 13:30:22 +0000 2021
# Hashtags: ['COVID19']
# Favourites: 48
# Retweets: 26
# URL: https://twitter.com/WHO/status/1412765940375302147
#
#
#
# Tweet index: 1718
# Tweet: Hep B birthdose for babies can't wait:
# The vaccine protects your 👶 from this potentially life-threatening liver infection that can cause both acute &amp; chronic disease. #Hepatitis B can put people at high risk of death ☠️ from liver damage &amp; liver cancer
#
# 👉https://t.co/Em4LYylVms https://t.co/GVXr0WtdOw
# Username: World Health Organization (WHO)
# Date: Wed Jul 28 12:13:41 +0000 2021
# Hashtags: ['Hepatitis']
# Favourites: 161
# Retweets: 64
# URL: https://twitter.com/WHO/status/1420356787652419584
#
#
#
# Tweet index: 969
# Tweet: @DrTedros "3rd dose may be necessary for at most risk ppl, where there's evidence of waning immunity against severe #COVID19 disease &amp; death – such as the small group of immunocompromised ppl who didn't respond sufficiently to initial doses, or are no longer producing antibodies"-@DrTedros
# Username: World Health Organization (WHO)
# Date: Wed Sep 01 15:13:26 +0000 2021
# Hashtags: ['COVID19']
# Favourites: 72
# Retweets: 35
# URL: https://twitter.com/WHO/status/1433085596617121797
#
#
#
# Tweet index: 2289
# Tweet: 8 of the 41 SIDS face pressing health workforce challenges related to #HealthForAll.
#
# #COVID19 has heavily impacted the health workers – including their heightened risk of infection &amp; death, burnout, fatigue, discrimination &amp; mental health issues. https://t.co/xGEJBModDa
# Username: World Health Organization (WHO)
# Date: Tue Jun 29 13:53:43 +0000 2021
# Hashtags: ['HealthForAll', 'COVID19']
# Favourites: 28
# Retweets: 11
# URL: https://twitter.com/WHO/status/1409872711355187200
#
#
#
# ###############################################################
#
#
# ['1005', '1004', '996', '2114', '2091', '1698', '2121', '1643', '468', '635', '485', '1928', '1154', '292', '1673', '1081', '1978', '1678', '1129', '496']
# Top 20 tweets from query "world pandemic":
# Tweet index: 1005
# Tweet: @DrTedros "But the lessons from West Africa were not sufficient to prepare the world for a global pandemic of a respiratory pathogen"-@DrTedros https://t.co/BIB3WZmPep
# Username: World Health Organization (WHO)
# Date: Wed Sep 01 14:13:49 +0000 2021
# Hashtags: []
# Favourites: 48
# Retweets: 20
# URL: https://twitter.com/WHO/status/1433070593721749506
#
#
#
# Tweet index: 1004
# Tweet: @DrTedros "The #COVID19 pandemic is the defining crisis of our time. It has taught the world many painful lessons"-@DrTedros
# Username: World Health Organization (WHO)
# Date: Wed Sep 01 14:14:20 +0000 2021
# Hashtags: ['COVID19']
# Favourites: 49
# Retweets: 14
# URL: https://twitter.com/WHO/status/1433070724781154310
#
#
#
# Tweet index: 996
# Tweet: @DrTedros "There have been several reviews of the global response to the #COVID19 pandemic, with recommendations for countries and for WHO about what we can do to keep the world safer in future"-@DrTedros
# Username: World Health Organization (WHO)
# Date: Wed Sep 01 14:29:07 +0000 2021
# Hashtags: ['COVID19']
# Favourites: 51
# Retweets: 9
# URL: https://twitter.com/WHO/status/1433074445476933640
#
#
#
# Tweet index: 2114
# Tweet: @DrTedros "From a moral, epidemiological or economic point view, now is the time for the world to come together to tackle this pandemic collectively"-@DrTedros #COVID19 #VaccinEquity
# https://t.co/ip4HvF2SRR
# Username: World Health Organization (WHO)
# Date: Wed Jul 07 13:22:22 +0000 2021
# Hashtags: ['COVID19', 'VaccinEquity']
# Favourites: 91
# Retweets: 50
# URL: https://twitter.com/WHO/status/1412763926039830534
#
#
#
# Tweet index: 2091
# Tweet: RT @DrTedros: The world is at a perilous point in the #COVID19 pandemic. We have just passed the tragic milestone of 4 million recorded dea…
# Username: World Health Organization (WHO)
# Date: Wed Jul 07 20:47:34 +0000 2021
# Hashtags: ['COVID19']
# Favourites: 0
# Retweets: 439
# URL: https://twitter.com/WHO/status/1412875962795143169
#
#
#
# Tweet index: 1698
# Tweet: "The #COVID19 pandemic has revealed two critical areas in which the world needs to do far more to bolster global health security: strengthening and sharing."-@DrMikeRyan
# Username: World Health Organization (WHO)
# Date: Wed Jul 28 20:48:43 +0000 2021
# Hashtags: ['COVID19']
# Favourites: 25
# Retweets: 11
# URL: https://twitter.com/WHO/status/1420486398243745795
#
#
#
# Tweet index: 2121
# Tweet: "The world is at a perilous point in this pandemic.
#
# We have just passed the tragic milestone of 4 million recorded #COVID19 deaths, which likely underestimates the overall toll"-@DrTedros
# Username: World Health Organization (WHO)
# Date: Wed Jul 07 13:18:53 +0000 2021
# Hashtags: ['COVID19']
# Favourites: 85
# Retweets: 52
# URL: https://twitter.com/WHO/status/1412763048071344128
#
#
#
# Tweet index: 1643
# Tweet: @DrTedros "My answer was that the #COVID19 pandemic will end when the world chooses to end it. It’s in our hands.
#
# We have all the tools we need: we can prevent this disease, we can test for it, and we can treat it"-@DrTedros #Tokyo2020 https://t.co/bmHXwlUDAa
# Username: World Health Organization (WHO)
# Date: Fri Jul 30 14:22:33 +0000 2021
# Hashtags: ['COVID19', 'Tokyo2020']
# Favourites: 83
# Retweets: 39
# URL: https://twitter.com/WHO/status/1421113993574420486
#
#
#
# Tweet index: 468
# Tweet: The new story drew from the responses to a survey of more than 5000 children, parents, caregivers and teachers from around the world who were asked to describe the challenges they continue to face in the second year of the #COVID19 pandemic https://t.co/JiURHzrEDP https://t.co/U5mvGbqPSN
# Username: World Health Organization (WHO)
# Date: Mon Sep 27 06:57:53 +0000 2021
# Hashtags: ['COVID19']
# Favourites: 126
# Retweets: 25
# URL: https://twitter.com/WHO/status/1442382972125069312
#
#
#
# Tweet index: 635
# Tweet: At the 76th #UNGA, WHO is urging world leaders to
#
# 1⃣ guarantee equitable access to #COVID19 vaccines &amp; life-saving tools
# 2⃣ ensure better pandemic preparedness
# 3⃣ get the @GlobalGoalsUN back on track
#
# Read more 👉https://t.co/gQ60gbT6WP https://t.co/aXObgfbcNi
# Username: World Health Organization (WHO)
# Date: Tue Sep 21 08:57:50 +0000 2021
# Hashtags: ['UNGA', 'COVID19']
# Favourites: 467
# Retweets: 156
# URL: https://twitter.com/WHO/status/1440238829999329281
#
#
#
# Tweet index: 485
# Tweet: WHO &amp; partners continue responding to #COVID19 around the world:
#
# 📍 implementing Resurgence Response Plan in #Uganda 🇺🇬
# 📍 strengthening #Uzbekistan 🇺🇿's pandemic preparedness
# 📍 delivering medical supplies &amp; training to #Guatemala 🇬🇹
#
# 👉https://t.co/uElpVwoohK #WHOImpact https://t.co/tEBkEzzXSc
# Username: World Health Organization (WHO)
# Date: Sat Sep 25 18:07:05 +0000 2021
# Hashtags: ['COVID19', 'Uganda', 'Uzbekistan', 'Guatemala', 'WHOImpact']
# Favourites: 108
# Retweets: 28
# URL: https://twitter.com/WHO/status/1441826605303681026
#
#
#
# Tweet index: 1928
# Tweet: @Olympics @DrTedros "Anyone who thinks #COVID19 the pandemic is over because it’s over where they live is living in a fool’s paradise. Vaccines are powerful and essential tools. But the world has not used them well"-@DrTedros #Tokyo2020 #AGoal4All
#
# https://t.co/yHGo73V5y7
# Username: World Health Organization (WHO)
# Date: Wed Jul 21 00:24:48 +0000 2021
# Hashtags: ['COVID19', 'Tokyo2020', 'AGoal4All']
# Favourites: 122
# Retweets: 67
# URL: https://twitter.com/WHO/status/1417641674734456834
#
#
#
# Tweet index: 1154
# Tweet: "The first part of that hope was realized – the development and approval of several safe and effective vaccines in record time has given the world real hope of bringing the [#COVID19] pandemic under control."-@DrTedros at #RC71AFRO
# Username: World Health Organization (WHO)
# Date: Tue Aug 24 09:03:51 +0000 2021
# Hashtags: ['COVID19', 'RC71AFRO']
# Favourites: 27
# Retweets: 6
# URL: https://twitter.com/WHO/status/1430093487110828052
#
#
#
# Tweet index: 292
# Tweet: The #COVID19 pandemic has reversed progress towards the @GlobalGoalsUN. But it also provides us with new opportunities to truly collaborate 🤝 on building back better – towards
#
# 🔽
# 🔽
# 🔽
#
# a healthier, fairer, more inclusive &amp; sustainable world. #UNGA https://t.co/7zoeMVN7vi
# Username: World Health Organization (WHO)
# Date: Thu Sep 30 15:39:07 +0000 2021
# Hashtags: ['COVID19', 'UNGA']
# Favourites: 73
# Retweets: 16
# URL: https://twitter.com/WHO/status/1443601307131158531
#
#
#
# Tweet index: 1673
# Tweet: "At the World Health Assembly in May, Member States agreed to hold a Special Session of the Assembly in November to consider developing a WHO convention, agreement or other type of international instrument on pandemic preparedness and response."-@DrMikeRyan
# Username: World Health Organization (WHO)
# Date: Wed Jul 28 20:56:47 +0000 2021
# Hashtags: []
# Favourites: 27
# Retweets: 7
# URL: https://twitter.com/WHO/status/1420488429180276751
#
#
#
# Tweet index: 1081
# Tweet: "With the @UN General Assembly in September, the @g20org Summit in October and the Special Session of the World Health Assembly in November, the next three months will be a critical period for shaping the future of pandemic preparedness and response."-@DrTedros
# Username: World Health Organization (WHO)
# Date: Wed Aug 25 15:41:09 +0000 2021
# Hashtags: []
# Favourites: 39
# Retweets: 15
# URL: https://twitter.com/WHO/status/1430555858585403393
#
#
#
# Tweet index: 1978
# Tweet: @DrTedros @jensspahn @ACTAccelerator "If the 🌍 continues down the same road, it will continue heading towards the same destination, which is an unsafe world, and another devastating pandemic is inevitable. We need a new approach, and a new way of doing things"-@DrTedros #PandemicTreaty
# Username: World Health Organization (WHO)
# Date: Thu Jul 15 12:26:53 +0000 2021
# Hashtags: ['PandemicTreaty']
# Favourites: 78
# Retweets: 26
# URL: https://twitter.com/WHO/status/1415649064243417090
#
#
#
# Tweet index: 1678
# Tweet: "But above and beyond improved mechanisms, improved tools and improved financing, the world needs an improved framework for pandemic preparedness and response."-@DrMikeRyan
# Username: World Health Organization (WHO)
# Date: Wed Jul 28 20:55:32 +0000 2021
# Hashtags: []
# Favourites: 18
# Retweets: 5
# URL: https://twitter.com/WHO/status/1420488114842312707
#
#
#
# Tweet index: 1129
# Tweet: "You will also be discussing the challenges facing our organization, including the challenge of sustainable financing.
# The pandemic has shown that the world needs an empowered and sustainably financed WHO at the centre of the global health architecture."-@DrTedros at #RC71AFRO
# Username: World Health Organization (WHO)
# Date: Tue Aug 24 09:34:08 +0000 2021
# Hashtags: ['RC71AFRO']
# Favourites: 31
# Retweets: 9
# URL: https://twitter.com/WHO/status/1430101107045453824
#
#
#
# Tweet index: 496
# Tweet: "Commitments alone won’t save lives, stop transmission, immunize people, scale up manufacturing capacity, and ready the world to prevent future health emergencies. What is needed now is for commitments to turn into immediate actions to equitably end the pandemic"- @DrTedros
# Username: World Health Organization (WHO)
# Date: Fri Sep 24 18:03:43 +0000 2021
# Hashtags: []
# Favourites: 81
# Retweets: 23
# URL: https://twitter.com/WHO/status/1441463370331435011
#
#
#
# ###############################################################
#
#
# ['1048', '627', '1284', '2147', '2316', '877', '290', '291', '1755', '1456', '294', '156', '1219', '1542', '938', '40', '1493', '1459', '1337', '615']
# Top 20 tweets from query "health service":
# Tweet index: 1048
# Tweet: Compassion - why is it important in health care, both for those who give and those who receive health services? https://t.co/6jgRM3fMNQ https://t.co/r6boOGPANS
# Username: World Health Organization (WHO)
# Date: Sun Aug 29 18:08:00 +0000 2021
# Hashtags: []
# Favourites: 579
# Retweets: 141
# URL: https://twitter.com/WHO/status/1432042366211403785
#
#
#
# Tweet index: 627
# Tweet: RT @DrTedros: Health is a service that needs to be continued at all times. If #Afghanistan's health system collapses, the tragedy will be w…
# Username: World Health Organization (WHO)
# Date: Tue Sep 21 11:34:26 +0000 2021
# Hashtags: ['Afghanistan']
# Favourites: 0
# Retweets: 115
# URL: https://twitter.com/WHO/status/1440278241814536192
#
#
#
# Tweet index: 1284
# Tweet: RT @WHOEMRO: During this challenging period, the delivery of essential health services must be maintained, and health workers respected and…
# Username: World Health Organization (WHO)
# Date: Mon Aug 16 21:41:03 +0000 2021
# Hashtags: []
# Favourites: 0
# Retweets: 19
# URL: https://twitter.com/WHO/status/1427384938299543554
#
#
#
# Tweet index: 2147
# Tweet: Limited electricity, lack of fuel, damaged telecommunications equipment, no cellular service = barriers to delivering life-saving health services to people in #Tigray, 🇪🇹. WHO must be able to provide medical supplies for #healthworkers to use in clinics, hospitals. https://t.co/zWLQ3kc9WF
# Username: World Health Organization (WHO)
# Date: Tue Jul 06 12:17:35 +0000 2021
# Hashtags: ['Tigray', 'healthworkers']
# Favourites: 854
# Retweets: 574
# URL: https://twitter.com/WHO/status/1412385236567068673
#
#
#
# Tweet index: 2316
# Tweet: To #BeatNCDs in SIDS, WHO calls for:
# - an Action Centre to effectively address noncommunicable diseases &amp; mental health
# -more resources to support health services
# -integration of mental health considerations into health system strengthening https://t.co/ctYiSQo2Ez https://t.co/ZcgWs1oHNS
# Username: World Health Organization (WHO)
# Date: Mon Jun 28 14:08:28 +0000 2021
# Hashtags: ['BeatNCDs']
# Favourites: 119
# Retweets: 34
# URL: https://twitter.com/WHO/status/1409514036232953856
#
#
#
# Tweet index: 877
# Tweet: The right health information can help people with disabilities get access to the right health services.
#
# Let's build a disability-inclusive health sector &amp; leave no one behind 👉https://t.co/Qrp2lez1JC #HealthForAll https://t.co/9SfGPxRpZc
# Username: World Health Organization (WHO)
# Date: Wed Sep 08 11:23:05 +0000 2021
# Hashtags: ['HealthForAll']
# Favourites: 113
# Retweets: 38
# URL: https://twitter.com/WHO/status/1435564343681183746
#
#
#
# Tweet index: 290
# Tweet: Health is a human right.
# Everyone, everywhere deserves access to quality essential health services.
# You can show your support for #HealthForAll by participating in Universal Health Coverage on 12.12.21.
# Get ready and learn more: https://t.co/iGkmFYqFWe
# Username: World Health Organization (WHO)
# Date: Thu Sep 30 16:34:42 +0000 2021
# Hashtags: ['HealthForAll']
# Favourites: 79
# Retweets: 18
# URL: https://twitter.com/WHO/status/1443615298255532032
#
#
#
# Tweet index: 291
# Tweet: Do you believe all people should have access to the health services without suffering financial hardship?
# Then get ready for Universal Health Coverage Day on 12.12.21! Join the call for leaders to invest in health systems that leave no one behind: https://t.co/iGkmFYqFWe https://t.co/A8X4ZcQwa3
# Username: World Health Organization (WHO)
# Date: Thu Sep 30 16:10:29 +0000 2021
# Hashtags: []
# Favourites: 135
# Retweets: 36
# URL: https://twitter.com/WHO/status/1443609202023440391
#
#
#
# Tweet index: 1755
# Tweet: #Mongolia 🇲🇳 is bringing health services to remote communities by using mobile health technologies to reach nomadic populations, migrants and unregistered people.
#
# 👉https://t.co/PYSjgi3F5i #WHOImpact #UHCPartnership https://t.co/sN9B8BP5ti
# Username: World Health Organization (WHO)
# Date: Tue Jul 27 08:47:20 +0000 2021
# Hashtags: ['Mongolia', 'WHOImpact', 'UHCPartnership']
# Favourites: 183
# Retweets: 36
# URL: https://twitter.com/WHO/status/1419942469404299266
#
#
#
# Tweet index: 1456
# Tweet: #Uzbekistan 🇺🇿‘s state health insurance fund covers #PrimaryHealthCare services so people can access vital health care, without falling into poverty.
#
# 👉https://t.co/PYSjgi3F5i #WHOImpact #UHCPartnership https://t.co/5OGgrWYkvH
# Username: World Health Organization (WHO)
# Date: Sat Aug 07 07:48:45 +0000 2021
# Hashtags: ['Uzbekistan', 'PrimaryHealthCare', 'WHOImpact', 'UHCPartnership']
# Favourites: 111
# Retweets: 28
# URL: https://twitter.com/WHO/status/1423913992712380418
#
#
#
# Tweet index: 294
# Tweet: #PrimaryHealthCare provides the first line of defense &amp; response to keep people safe &amp; healthy by strengthening health service delivery, essential public health functions and emergency risk management, and by involving communities in decisions about their health. https://t.co/edb5C5qFdO
# Username: World Health Organization (WHO)
# Date: Thu Sep 30 14:14:13 +0000 2021
# Hashtags: ['PrimaryHealthCare']
# Favourites: 136
# Retweets: 46
# URL: https://twitter.com/WHO/status/1443579942881558541
#
#
#
# Tweet index: 156
# Tweet: The world has failed to provide people with the #MentalHealth services they need: new Mental Health Atlas
# Read more➡️https://t.co/J0uKvKWZ46 https://t.co/0wKx6JTV2F
# Username: World Health Organization (WHO)
# Date: Fri Oct 08 10:37:58 +0000 2021
# Hashtags: ['MentalHealth']
# Favourites: 776
# Retweets: 322
# URL: https://twitter.com/WHO/status/1446424624141684738
#
#
#
# Tweet index: 1219
# Tweet: RT @DrTedros: .@WHO staff remain in #Afghanistan and committed to delivering health services to the most vulnerable. Yesterday, we dispatch…
# Username: World Health Organization (WHO)
# Date: Thu Aug 19 05:21:05 +0000 2021
# Hashtags: ['Afghanistan']
# Favourites: 0
# Retweets: 70
# URL: https://twitter.com/WHO/status/1428225483397869571
#
#
#
# Tweet index: 1542
# Tweet: During #COVID19, more than ever, 👨‍⚕️👩‍⚕️ must be protected &amp; respected, &amp; hospitals &amp; health facilities &amp; transportation, incl. 🚑 should not be used for military purposes – essential conditions for the continued delivery of critical health services.
#
# 👉 https://t.co/Od1Z7BYhB3 https://t.co/ayufWQQaT5
# Username: World Health Organization (WHO)
# Date: Tue Aug 03 13:05:19 +0000 2021
# Hashtags: ['COVID19']
# Favourites: 419
# Retweets: 120
# URL: https://twitter.com/WHO/status/1422544108460064774
#
#
#
# Tweet index: 938
# Tweet: More support is needed for people with #dementia, in
#
# ✅ primary health care
# ✅ specialist care
# ✅ community-based services
# ✅ rehabilitation
# ✅ long-term care
# ✅ palliative care.
#
# More info 👉https://t.co/ET2n0by75O https://t.co/H7M6k8Dyqa
# Username: World Health Organization (WHO)
# Date: Thu Sep 02 12:49:20 +0000 2021
# Hashtags: ['dementia']
# Favourites: 130
# Retweets: 47
# URL: https://twitter.com/WHO/status/1433411723046776840
#
#
#
# Tweet index: 40
# Tweet: RT @WHONAMIBIA: Today is #WorldMentalHealthDay!
#
# The #COVID19 pandemic has significantly disrupted mental health care services.
#
# It’s tim…
# Username: World Health Organization (WHO)
# Date: Mon Oct 11 04:47:14 +0000 2021
# Hashtags: ['WorldMentalHealthDay', 'COVID19']
# Favourites: 0
# Retweets: 53
# URL: https://twitter.com/WHO/status/1447423522339495936
#
#
#
# Tweet index: 1493
# Tweet: RT @DrTedros: .@WHO &amp; partners are:
# 1. providing access to life-saving health services for those worst-affected by the crisis
# 2. supporting…
# Username: World Health Organization (WHO)
# Date: Wed Aug 04 19:13:16 +0000 2021
# Hashtags: []
# Favourites: 0
# Retweets: 26
# URL: https://twitter.com/WHO/status/1422999094042169344
#
#
#
# Tweet index: 1459
# Tweet: #India 🇮🇳 is bringing health services closer to communities by strengthening its network of #PrimaryHealthCare centres.
#
# Read more 👉https://t.co/PYSjgi3F5i #WHOImpact #UHCPartnership https://t.co/IdZkkgxhYF
# Username: World Health Organization (WHO)
# Date: Sat Aug 07 06:18:07 +0000 2021
# Hashtags: ['India', 'PrimaryHealthCare', 'WHOImpact', 'UHCPartnership']
# Favourites: 184
# Retweets: 37
# URL: https://twitter.com/WHO/status/1423891184078901250
#
#
#
# Tweet index: 1337
# Tweet: RT @WHO_Europe: Keeping safe from #wildfires 🔥 is a joint effort between individuals, communities &amp; public health services.
#
# This is what p…
# Username: World Health Organization (WHO)
# Date: Fri Aug 13 15:30:05 +0000 2021
# Hashtags: ['wildfires']
# Favourites: 0
# Retweets: 20
# URL: https://twitter.com/WHO/status/1426204418157039616
#
#
#
# Tweet index: 615
# Tweet: @DrTedros @WHOEMRO @WHOAfghanistan @UN_News_Centre @UNNewsArabic Only 17% of all Sehatmandi health facilities in #Afghanistan are fully functional. This breakdown in health services is having a rippling effect on the availability of basic &amp; essential health care, emergency response, polio eradication, &amp; #COVID19 vaccination efforts. https://t.co/8morZ3IEbt
# Username: World Health Organization (WHO)
# Date: Wed Sep 22 09:00:40 +0000 2021
# Hashtags: ['Afghanistan', 'COVID19']
# Favourites: 50
# Retweets: 18
# URL: https://twitter.com/WHO/status/1440601933933264901
#
#
#
# ###############################################################
#
#
# ['2253', '2370', '606', '2251', '177', '1843', '115', '263', '2254', '1213', '511', '1962', '196']
# Top 20 tweets from query "developing countries":
# Tweet index: 2253
# Tweet: The heads of the four organizations discussed the urgency of increasing supplies of #COVID19 vaccines, therapeutics and diagnostics for developing countries; and practical &amp; effective ways to track, coordinate and advance delivery of COVID-19 vaccines to developing countries. https://t.co/fpISmcwQc2
# Username: World Health Organization (WHO)
# Date: Wed Jun 30 20:04:47 +0000 2021
# Hashtags: ['COVID19']
# Favourites: 67
# Retweets: 17
# URL: https://twitter.com/WHO/status/1410328481335029765
#
#
#
# Tweet index: 2370
# Tweet: @DrTedros "A further 87 countries either have teams that are in the process of being certified by WHO, or are developing systems to quality-assure their own national teams"-@DrTedros
# https://t.co/WWdwh23cUf
# Username: World Health Organization (WHO)
# Date: Fri Jun 25 15:39:05 +0000 2021
# Hashtags: []
# Favourites: 38
# Retweets: 10
# URL: https://twitter.com/WHO/status/1408449677490536448
#
#
#
# Tweet index: 606
# Tweet: "#AirPollution is a health threat in all countries, but especially for vulnerable groups in low- and middle-income countries with poor air quality due to urbanization and rapid economic development, and air pollution in the home caused by cooking, heating and lighting"-@DrTedros
# Username: World Health Organization (WHO)
# Date: Wed Sep 22 13:20:51 +0000 2021
# Hashtags: ['AirPollution']
# Favourites: 208
# Retweets: 67
# URL: https://twitter.com/WHO/status/1440667411309498373
#
#
#
# Tweet index: 2251
# Tweet: RT @DrTedros: We have formed a Task Force to help track, coordinate and advance delivery of #COVID19 health tools to developing countries a…
# Username: World Health Organization (WHO)
# Date: Wed Jun 30 22:21:31 +0000 2021
# Hashtags: ['COVID19']
# Favourites: 0
# Retweets: 41
# URL: https://twitter.com/WHO/status/1410362891698642948
#
#
#
# Tweet index: 177
# Tweet: "We call on global and regional multilateral development banks to support countries to more rapidly access the capital they need to fund #COVID19 vaccine delivery programmes"-@DrTedros #VaccinEquity
# Username: World Health Organization (WHO)
# Date: Thu Oct 07 13:59:20 +0000 2021
# Hashtags: ['COVID19', 'VaccinEquity']
# Favourites: 137
# Retweets: 36
# URL: https://twitter.com/WHO/status/1446112913962385483
#
#
#
# Tweet index: 1843
# Tweet: The #VaccinEquity Dashboard from WHO, @UNDP, and @BlavatnikSchool shows that low- and lower-middle-income countries must have access to vaccines now to:
# 👩‍⚕️Save lives
# 💹Promote economic recovery
# 👨‍👩‍👧‍👦Advance human development
#
# https://t.co/48frkTNNmC https://t.co/zAnwTQfX3f
# Username: World Health Organization (WHO)
# Date: Thu Jul 22 16:03:47 +0000 2021
# Hashtags: ['VaccinEquity']
# Favourites: 100
# Retweets: 52
# URL: https://twitter.com/WHO/status/1418240365086355456
#
#
#
# Tweet index: 115
# Tweet: Measuring the development of #PalliativeCare helps countries to
#
# 🚩 understand where the key gaps are
# 🚩 advocate more concerted action
# 🚩 identify where resources are most needed
# 🚩 learn from best practices
#
# WHO report on palliative care explains how 👉https://t.co/tQvD47Ng26 https://t.co/HfWuWDmubm
# Username: World Health Organization (WHO)
# Date: Sat Oct 09 16:13:17 +0000 2021
# Hashtags: ['PalliativeCare']
# Favourites: 111
# Retweets: 28
# URL: https://twitter.com/WHO/status/1446871396123127808
#
#
#
# Tweet index: 263
# Tweet: Over 130 countries have used the WHO Essential Medicines List to develop their own national lists.
# The List is a powerful tool to increase access to treatment https://t.co/LfWwHEZtuM https://t.co/lyxbODYJ1Q
# Username: World Health Organization (WHO)
# Date: Sat Oct 02 10:53:25 +0000 2021
# Hashtags: []
# Favourites: 108
# Retweets: 22
# URL: https://twitter.com/WHO/status/1444254187307536385
#
#
#
# Tweet index: 2254
# Tweet: Joint statement from @DrTedros and @WorldBank Group’s @DavidMalpassWBG, @IMFNews’s @KGeorgieva and @wto’s @NOIweala who met today at the first meeting of the Task Force on #COVID19 Vaccines, Therapeutics and Diagnostics for Developing Countries https://t.co/xynmWWaC0z
# Username: World Health Organization (WHO)
# Date: Wed Jun 30 20:03:47 +0000 2021
# Hashtags: ['COVID19']
# Favourites: 131
# Retweets: 27
# URL: https://twitter.com/WHO/status/1410328232184983560
#
#
#
# Tweet index: 1213
# Tweet: Climate-related disasters, like floods, droughts &amp; heat waves, have doubled in the past 20 years, affecting people in developing countries the most.
#
# On #WorldHumanitarianDay, join #TheHumanRace to put their needs front and centre.
#
# 👉 https://t.co/v0SYzJ1gft https://t.co/dZFKDUIa3G
# Username: World Health Organization (WHO)
# Date: Thu Aug 19 09:15:03 +0000 2021
# Hashtags: ['WorldHumanitarianDay', 'TheHumanRace']
# Favourites: 220
# Retweets: 76
# URL: https://twitter.com/WHO/status/1428284364035604483
#
#
#
# Tweet index: 511
# Tweet: Lack of political will in several settings is blocking the implementation of #VaccinEquity and the development of well-resourced vaccination programmes at country level. Continued advocacy for equity is needed: The Independent Allocation Vaccine Group for COVAX https://t.co/m7ZXwoytVR
# Username: World Health Organization (WHO)
# Date: Fri Sep 24 17:20:46 +0000 2021
# Hashtags: ['VaccinEquity']
# Favourites: 24
# Retweets: 8
# URL: https://twitter.com/WHO/status/1441452563677827072
#
#
#
# Tweet index: 1962
# Tweet: The 🆕 report, which is based on clinical surveillance data from 37 countries, found that the risk of developing severe or fatal #COVID19 was 30% greater in people living with HIV compared to people without #HIV infection.
#
# 👉 https://t.co/UEV0LGJzYP https://t.co/UkxV1FlM2e
# Username: World Health Organization (WHO)
# Date: Fri Jul 16 12:38:02 +0000 2021
# Hashtags: ['COVID19', 'HIV']
# Favourites: 157
# Retweets: 64
# URL: https://twitter.com/WHO/status/1416014259759222790
#
#
#
# Tweet index: 196
# Tweet: @DrTedros @antonioguterres "The development and approval of #COVID19 vaccines in record time took us to the summit of scientific achievement; now we stand on the precipice of failure, if we don’t make the benefits of science available to all people in all countries, right now"-@DrTedros #VaccinEquity
# Username: World Health Organization (WHO)
# Date: Thu Oct 07 13:40:47 +0000 2021
# Hashtags: ['COVID19', 'VaccinEquity']
# Favourites: 165
# Retweets: 46
# URL: https://twitter.com/WHO/status/1446108242535272461
#
#
#
# ###############################################################
#
#
# No tweets found matching query: molta caca

# %%
# Interactive way of testing the engine (put your own query and select the ranking mode)
print("Insert your query:\n")
query = input()

print('\nInsert the type of ranking you want to follow:')
print('- Mode 1: Our score and ranking, taking into account the number of likes and followers')
print('- Mode 2: Word2Vec score')
print('- Otherwise: Use the initial tf-idf score')
mode = input()
ranked_tweets, tmp = query_output(query_text, index , idf, tf, likes, followers, retweets, tweets, mode_, model)
top = 20

if ranked_tweets:
    print("\n======================\nTop {} results out of {} for the searched query:\n".format(top, len(ranked_tweets)))
    display_tweets(ranked_tweets[:top])
# Out:
# Insert your query:
#
# hola:)
#
# Insert the type of ranking you want to follow:
# - Mode 1: Our score and ranking, taking into account the number of likes and followers
# - Mode 2: Word2Vec score
# - Otherwise: Use the initial tf-idf score
# 2
#
# ======================
# Top 20 results out of 1 for the searched query:
#
# No tweets found matching this query
